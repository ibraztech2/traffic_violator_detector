# %% [markdown]
# <a href="https://colab.research.google.com/github/ibraztech2/VisionMarshal/blob/Violation-Email-Automation/vision_marshal_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# ---
# # ` VISION MARSHAL AI `
# ---
# ---

# %% [markdown]
# #  ***Backend Setup***

# %% [markdown]
# ## `1. Drive Mount`

# %%
# Check the version of cuda compiler available
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0

# %%
# %%time
#Mount drive to get acces to video input

#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# CPU times: user 1e+03 ns, sys: 1 µs, total: 2 µs
# Wall time: 4.53 µs

# %% [markdown]
# ## `2. MMAction2 installation And Dependencies Resolution`

# %% [markdown]
# ### 1. Downgrade Pytorch, Numpy, Transformers, Torchvision, Torchaudio to compatible Version

# %%
# %%time

# !pip uninstall -y torch torchvision torchaudio mmcv mmcv-full mmengine numpy torchao transformers
# !pip uninstall -y torch torchvision torchaudio numpy transformers


# Install PyTorch 2.1.0 with CUDA 11.8
# !pip install torch==2.1.0+cu118 torchvision==0.16.0+cu118 torchaudio==2.1.0 --index-url https://download.pytorch.org/whl/cu118
# Out:
# Found existing installation: torch 2.6.0+cu124
# Uninstalling torch-2.6.0+cu124:
#   Successfully uninstalled torch-2.6.0+cu124
# Found existing installation: torchvision 0.21.0+cu124
# Uninstalling torchvision-0.21.0+cu124:
#   Successfully uninstalled torchvision-0.21.0+cu124
# Found existing installation: torchaudio 2.6.0+cu124
# Uninstalling torchaudio-2.6.0+cu124:
#   Successfully uninstalled torchaudio-2.6.0+cu124
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
#   Successfully uninstalled numpy-2.0.2
# Found existing installation: transformers 4.54.0
# Uninstalling transformers-4.54.0:
#   Successfully uninstalled transformers-4.54.0
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch==2.1.0+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.1.0%2Bcu118-cp311-cp311-linux_x86_64.whl (2325.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 542.4 kB/s eta 0:00:00
# Collecting torchvision==0.16.0+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.16.0%2Bcu118-cp311-cp311-linux_x86_64.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 112.9 MB/s eta 0:00:00
# Collecting torchaudio==2.1.0
#   Downloading https://download.pytorch.org/whl/cu118/torchaudio-2.1.0%2Bcu118-cp311-cp311-linux_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 92.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.1.0+cu118) (3.18.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch==2.1.0+cu118) (4.14.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.1.0+cu118) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.1.0+cu118) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.1.0+cu118) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.1.0+cu118) (2025.3.0)
# Collecting triton==2.1.0 (from torch==2.1.0+cu118)
#   Downloading https://download.pytorch.org/whl/triton-2.1.0-0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 8.1 MB/s eta 0:00:00
# Collecting numpy (from torchvision==0.16.0+cu118)
#   Downloading https://download.pytorch.org/whl/numpy-2.1.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchvision==0.16.0+cu118) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.16.0+cu118) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.1.0+cu118) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.16.0+cu118) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.16.0+cu118) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.16.0+cu118) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.16.0+cu118) (2025.7.14)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.1.0+cu118) (1.3.0)
# Downloading https://download.pytorch.org/whl/numpy-2.1.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 98.7 MB/s eta 0:00:00
# Installing collected packages: triton, numpy, torch, torchvision, torchaudio
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, which is not installed.
# peft 0.16.0 requires transformers, which is not installed.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.1.2 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.1.2 which is incompatible.
# Successfully installed numpy-2.1.2 torch-2.1.0+cu118 torchaudio-2.1.0+cu118 torchvision-0.16.0+cu118 triton-2.1.0
# CPU times: user 2.96 s, sys: 1.25 s, total: 4.21 s
# Wall time: 2min 36s

# %% [markdown]
# ### 2. Install MMCV and MMengine

# %%
# %%time

# Install MMCV 2.1.0 and mmengine
# !pip install mmcv==2.1.0 -f https://download.openmmlab.com/mmcv/dist/cu118/torch2.1/index.html
# !pip install mmengine==0.10.3
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.1/index.html
# Collecting mmcv==2.1.0
#   Downloading https://download.openmmlab.com/mmcv/dist/cu118/torch2.1.0/mmcv-2.1.0-cp311-cp311-manylinux1_x86_64.whl (99.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 MB 7.6 MB/s eta 0:00:00
# Collecting addict (from mmcv==2.1.0)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting mmengine>=0.3.0 (from mmcv==2.1.0)
#   Downloading mmengine-0.10.7-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmcv==2.1.0) (2.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mmcv==2.1.0) (25.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from mmcv==2.1.0) (11.3.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from mmcv==2.1.0) (6.0.2)
# Collecting yapf (from mmcv==2.1.0)
#   Downloading yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.11/dist-packages (from mmcv==2.1.0) (4.12.0.88)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mmengine>=0.3.0->mmcv==2.1.0) (3.10.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from mmengine>=0.3.0->mmcv==2.1.0) (13.9.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from mmengine>=0.3.0->mmcv==2.1.0) (3.1.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from yapf->mmcv==2.1.0) (4.3.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->mmengine>=0.3.0->mmcv==2.1.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->mmengine>=0.3.0->mmcv==2.1.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv==2.1.0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.17.0)
# Downloading mmengine-0.10.7-py3-none-any.whl (452 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.7/452.7 kB 32.6 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading yapf-0.43.0-py3-none-any.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 22.4 MB/s eta 0:00:00
# Installing collected packages: addict, yapf, mmengine, mmcv
# Successfully installed addict-2.4.0 mmcv-2.1.0 mmengine-0.10.7 yapf-0.43.0
# Collecting mmengine==0.10.3
#   Downloading mmengine-0.10.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: addict in /usr/local/lib/python3.11/dist-packages (from mmengine==0.10.3) (2.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mmengine==0.10.3) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmengine==0.10.3) (2.1.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from mmengine==0.10.3) (6.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from mmengine==0.10.3) (13.9.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from mmengine==0.10.3) (3.1.0)
# Requirement already satisfied: yapf in /usr/local/lib/python3.11/dist-packages (from mmengine==0.10.3) (0.43.0)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.11/dist-packages (from mmengine==0.10.3) (4.12.0.88)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine==0.10.3) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine==0.10.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine==0.10.3) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine==0.10.3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine==0.10.3) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine==0.10.3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine==0.10.3) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine==0.10.3) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->mmengine==0.10.3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->mmengine==0.10.3) (2.19.2)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from yapf->mmengine==0.10.3) (4.3.8)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine==0.10.3) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine==0.10.3) (1.17.0)
# Downloading mmengine-0.10.3-py3-none-any.whl (451 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.7/451.7 kB 30.2 MB/s eta 0:00:00
# Installing collected packages: mmengine
#   Attempting uninstall: mmengine
#     Found existing installation: mmengine 0.10.7
#     Uninstalling mmengine-0.10.7:
#       Successfully uninstalled mmengine-0.10.7
# Successfully installed mmengine-0.10.3
# CPU times: user 3.58 s, sys: 704 ms, total: 4.28 s
# Wall time: 21.9 s

# %% [markdown]
# ### 3. Install OpenMIM ( command line tool for MMAction and  MMdetection )

# %%
# %%time

# Install OpenMIM
# !pip install -U openmim
# Out:
# Collecting openmim
#   Downloading openmim-0.3.9-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: Click in /usr/local/lib/python3.11/dist-packages (from openmim) (8.2.1)
# Collecting colorama (from openmim)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting model-index (from openmim)
#   Downloading model_index-0.1.11-py3-none-any.whl.metadata (3.9 kB)
# Collecting opendatalab (from openmim)
#   Downloading opendatalab-0.0.10-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from openmim) (2.2.2)
# Requirement already satisfied: pip>=19.3 in /usr/local/lib/python3.11/dist-packages (from openmim) (24.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from openmim) (2.32.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from openmim) (13.9.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from model-index->openmim) (6.0.2)
# Requirement already satisfied: markdown in /usr/local/lib/python3.11/dist-packages (from model-index->openmim) (3.8.2)
# Collecting ordered-set (from model-index->openmim)
#   Downloading ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pycryptodome (from opendatalab->openmim)
#   Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from opendatalab->openmim) (4.67.1)
# Collecting openxlab (from opendatalab->openmim)
#   Downloading openxlab-0.1.2-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->openmim) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->openmim) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->openmim) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->openmim) (2025.7.14)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->openmim) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->openmim) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->openmim) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->openmim) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->openmim) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->openmim) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->openmim) (1.17.0)
# Collecting filelock~=3.14.0 (from openxlab->opendatalab->openmim)
#   Downloading filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting oss2~=2.17.0 (from openxlab->opendatalab->openmim)
#   Downloading oss2-2.17.0.tar.gz (259 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 24.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting packaging~=24.0 (from openxlab->opendatalab->openmim)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pytz>=2020.1 (from pandas->openmim)
#   Downloading pytz-2023.4-py2.py3-none-any.whl.metadata (22 kB)
# Collecting requests (from openmim)
#   Downloading requests-2.28.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich (from openmim)
#   Downloading rich-13.4.2-py3-none-any.whl.metadata (18 kB)
# Collecting setuptools~=60.2.0 (from openxlab->opendatalab->openmim)
#   Downloading setuptools-60.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting tqdm (from opendatalab->openmim)
#   Downloading tqdm-4.65.2-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 5.8 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1 (from requests->openmim)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 5.0 MB/s eta 0:00:00
# Collecting crcmod>=1.7 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 8.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun-python-sdk-core-2.16.0.tar.gz (449 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.6/449.6 kB 30.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: cryptography>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.22)
# Downloading openmim-0.3.9-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 2.8 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Downloading opendatalab-0.0.10-py3-none-any.whl (29 kB)
# Downloading openxlab-0.1.2-py3-none-any.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.5/311.5 kB 26.9 MB/s eta 0:00:00
# Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.4 MB/s eta 0:00:00
# Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 17.6 MB/s eta 0:00:00
# Downloading pytz-2023.4-py2.py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 kB 33.8 MB/s eta 0:00:00
# Downloading tqdm-4.65.2-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 7.4 MB/s eta 0:00:00
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 13.4 MB/s eta 0:00:00
# Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 84.2 MB/s eta 0:00:00
# Downloading filelock-3.14.0-py3-none-any.whl (12 kB)
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 6.5 MB/s eta 0:00:00
# Downloading setuptools-60.2.0-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.1/953.1 kB 63.6 MB/s eta 0:00:00
# Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.5/99.5 kB 8.9 MB/s eta 0:00:00
# Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Building wheels for collected packages: oss2, aliyun-python-sdk-core, crcmod
#   Building wheel for oss2 (setup.py) ... done
#   Created wheel for oss2: filename=oss2-2.17.0-py3-none-any.whl size=112371 sha256=d214e879443102a30db5acc770af17ef22d465c0d40996df62a1e656fbab7886
#   Stored in directory: /root/.cache/pip/wheels/42/79/aa/3671e313c27de35211d345d7a9d8ccb7dde515cf05edba75df
#   Building wheel for aliyun-python-sdk-core (setup.py) ... done
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.16.0-py3-none-any.whl size=535315 sha256=7b42d43de473d7d86af3cf736f2850c06ded9b759ea137fdd2e2a6415a66fafa
#   Stored in directory: /root/.cache/pip/wheels/2b/9a/95/60f111d2a488c5f7f7ed2a96ce407ea57ec7393ddfdec8c956
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp311-cp311-linux_x86_64.whl size=31659 sha256=13cfaec5b9166f2605be3a207ff569a1fbb0d2590deae3681f2458d7b40629e8
#   Stored in directory: /root/.cache/pip/wheels/23/94/7a/8cb7d14597e6395ce969933f01aed9ea8fa5f5b4d4c8a61e99
# Successfully built oss2 aliyun-python-sdk-core crcmod
# Installing collected packages: pytz, crcmod, urllib3, tqdm, setuptools, pycryptodome, packaging, ordered-set, jmespath, filelock, colorama, rich, requests, model-index, aliyun-python-sdk-core, aliyun-python-sdk-kms, oss2, openxlab, opendatalab, openmim
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.18.0
#     Uninstalling filelock-3.18.0:
#       Successfully uninstalled filelock-3.18.0
#   Attempting uninstall: rich
#     Found existing installation: rich 13.9.4
#     Uninstalling rich-13.9.4:
#       Successfully uninstalled rich-13.9.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, which is not installed.
# peft 0.16.0 requires transformers, which is not installed.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.28.2 which is incompatible.
# sphinx 8.2.3 requires requests>=2.30.0, but you have requests 2.28.2 which is incompatible.
# pymc 5.25.1 requires rich>=13.7.1, but you have rich 13.4.2 which is incompatible.
# datasets 4.0.0 requires requests>=2.32.2, but you have requests 2.28.2 which is incompatible.
# datasets 4.0.0 requires tqdm>=4.66.3, but you have tqdm 4.65.2 which is incompatible.
# yfinance 0.2.65 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.1.2 which is incompatible.
# pytensor 2.31.7 requires filelock>=3.15, but you have filelock 3.14.0 which is incompatible.
# dataproc-spark-connect 0.8.3 requires tqdm>=4.67, but you have tqdm 4.65.2 which is incompatible.
# Successfully installed aliyun-python-sdk-core-2.16.0 aliyun-python-sdk-kms-2.16.5 colorama-0.4.6 crcmod-1.7 filelock-3.14.0 jmespath-0.10.0 model-index-0.1.11 opendatalab-0.0.10 openmim-0.3.9 openxlab-0.1.2 ordered-set-4.1.0 oss2-2.17.0 packaging-24.2 pycryptodome-3.23.0 pytz-2023.4 requests-2.28.2 rich-13.4.2 setuptools-60.2.0 tqdm-4.65.2 urllib3-1.26.20
# CPU times: user 2.07 s, sys: 395 ms, total: 2.47 s
# Wall time: 27.1 s

# %% [markdown]
# ### 4. Build MMaction   from source

# %%
# Clone MMAction from Github

# !git clone https://github.com/open-mmlab/mmaction2.git
# %cd mmaction2
# !pip install -e .
# Out:
# Cloning into 'mmaction2'...
# remote: Enumerating objects: 22864, done.
# remote: Total 22864 (delta 0), reused 0 (delta 0), pack-reused 22864 (from 1)
# Receiving objects: 100% (22864/22864), 69.65 MiB | 11.95 MiB/s, done.
# Resolving deltas: 100% (16122/16122), done.
# /content/mmaction2
# Obtaining file:///content/mmaction2
#   Preparing metadata (setup.py) ... done
# Collecting decord>=0.4.1 (from mmaction2==1.2.0)
#   Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl.metadata (422 bytes)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (0.8.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (2.1.2)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (4.12.0.88)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (11.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (1.16.0)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2==1.2.0) (3.14.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2==1.2.0) (4.14.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2==1.2.0) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2==1.2.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2==1.2.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2==1.2.0) (2025.3.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2==1.2.0) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2==1.2.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2==1.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2==1.2.0) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2==1.2.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2==1.2.0) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2==1.2.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2==1.2.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mmaction2==1.2.0) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3->mmaction2==1.2.0) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch>=1.3->mmaction2==1.2.0) (1.3.0)
# Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 82.5 MB/s eta 0:00:00
# Installing collected packages: decord, mmaction2
#   Running setup.py develop for mmaction2
# Successfully installed decord-0.6.0 mmaction2-1.2.0

# %% [markdown]
# ### 5. Install Numpy compatible Version

# %%
# !pip install numpy==1.24.4
# Out:
# Collecting numpy==1.24.4
#   Downloading numpy-1.24.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Downloading numpy-1.24.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 95.4 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.2
#     Uninstalling numpy-2.1.2:
#       Successfully uninstalled numpy-2.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# peft 0.16.0 requires transformers, which is not installed.
# blosc2 3.6.1 requires numpy>=1.26, but you have numpy 1.24.4 which is incompatible.
# xarray-einstats 0.9.1 requires numpy>=1.25, but you have numpy 1.24.4 which is incompatible.
# jaxlib 0.5.1 requires numpy>=1.25, but you have numpy 1.24.4 which is incompatible.
# pymc 5.25.1 requires numpy>=1.25.0, but you have numpy 1.24.4 which is incompatible.
# pymc 5.25.1 requires rich>=13.7.1, but you have rich 13.4.2 which is incompatible.
# datasets 4.0.0 requires requests>=2.32.2, but you have requests 2.28.2 which is incompatible.
# datasets 4.0.0 requires tqdm>=4.66.3, but you have tqdm 4.65.2 which is incompatible.
# treescope 0.1.9 requires numpy>=1.25.2, but you have numpy 1.24.4 which is incompatible.
# yfinance 0.2.65 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.24.4 which is incompatible.
# arviz 0.22.0 requires numpy>=1.26.0, but you have numpy 1.24.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.24.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.24.4 which is incompatible.
# scipy 1.16.0 requires numpy<2.6,>=1.25.2, but you have numpy 1.24.4 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.24.4 which is incompatible.
# pytensor 2.31.7 requires filelock>=3.15, but you have filelock 3.14.0 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.24.4 which is incompatible.
# jax 0.5.2 requires numpy>=1.25, but you have numpy 1.24.4 which is incompatible.
# xarray 2025.7.1 requires numpy>=1.26, but you have numpy 1.24.4 which is incompatible.
# Successfully installed numpy-1.24.4

# %% [markdown]
# ### 6. Download  Temporal Segment Network ( Built on Imagenet ) configuration file and  checkpoint file

# %%
# downloading the configuration file to the given location

# !mim download mmaction2 --config tsn_imagenet-pretrained-r50_8xb32-1x1x8-100e_kinetics400-rgb --dest /content/mmaction2/
# Out:
# processing tsn_imagenet-pretrained-r50_8xb32-1x1x8-100e_kinetics400-rgb...
# downloading ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 MiB 32.5 MB/s eta 0:00:00
# Successfully downloaded tsn_imagenet-pretrained-r50_8xb32-1x1x8-100e_kinetics400-rgb_20220906-2692d16c.pth to /content/mmaction2
# Successfully dumped tsn_imagenet-pretrained-r50_8xb32-1x1x8-100e_kinetics400-rgb.py to /content/mmaction2

# %% [markdown]
# ### 7. Testing Setup for :

# %% [markdown]
# #### 1.  MMAction Setup on a demo video

# %%
# The demo.mp4 and label_map_k400.txt are both from Kinetics-400
# !python /content/mmaction2/demo/demo.py /content/mmaction2/tsn_imagenet-pretrained-r50_8xb32-1x1x8-100e_kinetics400-rgb.py \
    /content/mmaction2/tsn_imagenet-pretrained-r50_8xb32-1x1x8-100e_kinetics400-rgb_20220906-2692d16c.pth \
    /content/mmaction2/demo/demo.mp4 /content/mmaction2/tools/data/kinetics/label_map_k400.txt
# Out:
# Loads checkpoint by local backend from path: /content/mmaction2/tsn_imagenet-pretrained-r50_8xb32-1x1x8-100e_kinetics400-rgb_20220906-2692d16c.pth
# /usr/local/lib/python3.11/dist-packages/nltk/metrics/association.py:26: UserWarning: A NumPy version >=1.25.2 and <2.6.0 is required for this version of SciPy (detected version 1.24.4)
#   from scipy.stats import fisher_exact
# Traceback (most recent call last):
#   File "/content/mmaction2/demo/demo.py", line 158, in <module>
#     main()
#   File "/content/mmaction2/demo/demo.py", line 120, in main
#     pred_result = inference_recognizer(model, args.video)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/mmaction2/mmaction/apis/inference.py", line 80, in inference_recognizer
#     test_pipeline = Compose(test_pipeline_cfg)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mmengine/dataset/base_dataset.py", line 38, in __init__
#     transform = TRANSFORMS.build(transform)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mmengine/registry/registry.py", line 570, in build
#     return self.build_func(cfg, *args, **kwargs, registry=self)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mmengine/registry/build_functions.py", line 98, in build_from_cfg
#     obj_cls = registry.get(obj_type)
#               ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mmengine/registry/registry.py", line 451, in get
#     self.import_from_location()
#   File "/usr/local/lib/python3.11/dist-packages/mmengine/registry/registry.py", line 376, in import_from_location
#     import_module(loc)
#   File "/usr/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/content/mmaction2/mmaction/datasets/__init__.py", line 11, in <module>
#     from .transforms import *  # noqa: F401, F403
#     ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/mmaction2/mmaction/datasets/transforms/__init__.py", line 12, in <module>
#     from .pose_transforms import (DecompressPose, GeneratePoseTarget, GenSkeFeat,
#   File "/content/mmaction2/mmaction/datasets/transforms/pose_transforms.py", line 9, in <module>
#     from scipy.stats import mode
#   File "/usr/local/lib/python3.11/dist-packages/scipy/stats/__init__.py", line 626, in <module>
#     from ._stats_py import *
#   File "/usr/local/lib/python3.11/dist-packages/scipy/stats/_stats_py.py", line 39, in <module>
#     from scipy import sparse
#   File "/usr/local/lib/python3.11/dist-packages/scipy/__init__.py", line 131, in __getattr__
#     return _importlib.import_module(f'scipy.{name}')
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/scipy/sparse/__init__.py", line 304, in <module>
#     from ._base import *
#   File "/usr/local/lib/python3.11/dist-packages/scipy/sparse/_base.py", line 8, in <module>
#     from ._sputils import (asmatrix, check_reshape_kwargs, check_shape,
#   File "/usr/local/lib/python3.11/dist-packages/scipy/sparse/_sputils.py", line 10, in <module>
#     from scipy._lib._util import np_long, np_ulong
#   File "/usr/local/lib/python3.11/dist-packages/scipy/_lib/_util.py", line 20, in <module>
#     from numpy.exceptions import AxisError
# ModuleNotFoundError: No module named 'numpy.exceptions'

# %% [markdown]
# #### 2. MMDetcttion on a Demo picture

# %%
# !python /content/mmdetection/demo/image_demo.py /content/mmdetection/demo/demo.jpg /content/mmdetection/rtmdet_tiny_8xb32-300e_coco.py --weights /content/mmdetection/rtmdet_tiny_8xb32-300e_coco_20220902_112414-78e30dcc.pth --device cpu
# Out:
# python3: can't open file '/content/mmdetection/demo/image_demo.py': [Errno 2] No such file or directory

# %% [markdown]
# ## `3.  App File, Requirement and Checkpoint setup `

# %% [markdown]
# ### 1. Download Checkpoints  Files for Action recognition [Timesformer](https://mmaction2.readthedocs.io/en/latest/model_zoo/recognition.html#timesformer)

# %%
# Create Project  Tree Struscture
import os

os.makedirs("/content/smart_traffic_detector", exist_ok=True)

os.makedirs("/content/smart_traffic_detector/debug", exist_ok=True)
os.makedirs("/content/smart_traffic_detector/main", exist_ok=True)
os.makedirs("/content/smart_traffic_detector/checkpoints", exist_ok=True)
os.makedirs("/content/smart_traffic_detector/clips", exist_ok=True)
os.makedirs("/content/smart_traffic_detector/violations", exist_ok=True)
os.makedirs("/content/smart_traffic_detector/alerts", exist_ok=True)

# %%
# Download Model  Checkpoint  for ACtion Recognition

# !wget https://download.openmmlab.com/mmaction/v1.0/recognition/timesformer/timesformer_spaceOnly_8xb8-8x32x1-15e_kinetics400-rgb/timesformer_spaceOnly_8xb8-8x32x1-15e_kinetics400-rgb_20220815-78f05367.pth -P /content/smart_traffic_detector/checkpoints
#!wget https://download.openmmlab.com/mmaction/v1.0/recognition/slowfast/slowfast_r101_8xb8-8x8x1-256e_kinetics400-rgb/slowfast_r101_8xb8-8x8x1-256e_kinetics400-rgb_20220818-9c0e09bd.pth -P /content/smart_traffic_detector/checkpoints
#!wget https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_2x_coco/faster_rcnn_r50_fpn_2x_coco_bbox_mAP-0.384_20200504_210434-a5d8aa15.pth -P /content/smart_traffic_detector/checkpoints
# !wget https://github.com/open-mmlab/mmaction2/blob/main/tools/data/kinetics/label_map_k400.txt -P /content/smart_traffic_detector
# Out:
# --2025-08-06 15:57:00--  https://download.openmmlab.com/mmaction/v1.0/recognition/timesformer/timesformer_spaceOnly_8xb8-8x32x1-15e_kinetics400-rgb/timesformer_spaceOnly_8xb8-8x32x1-15e_kinetics400-rgb_20220815-78f05367.pth
# Resolving download.openmmlab.com (download.openmmlab.com)... 163.181.201.195, 163.181.201.196, 163.181.201.197, ...
# Connecting to download.openmmlab.com (download.openmmlab.com)|163.181.201.195|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 344501009 (329M) [application/octet-stream]
# Saving to: ‘/content/smart_traffic_detector/checkpoints/timesformer_spaceOnly_8xb8-8x32x1-15e_kinetics400-rgb_20220815-78f05367.pth’
#
# timesformer_spaceOn 100%[===================>] 328.54M  21.6MB/s    in 15s
#
# 2025-08-06 15:57:15 (21.4 MB/s) - ‘/content/smart_traffic_detector/checkpoints/timesformer_spaceOnly_8xb8-8x32x1-15e_kinetics400-rgb_20220815-78f05367.pth’ saved [344501009/344501009]
#
# --2025-08-06 15:57:15--  https://github.com/open-mmlab/mmaction2/blob/main/tools/data/kinetics/label_map_k400.txt
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/smart_traffic_detector/label_map_k400.txt’
#
# label_map_k400.txt      [ <=>                ] 193.30K  --.-KB/s    in 0.006s
#
# 2025-08-06 15:57:16 (33.1 MB/s) - ‘/content/smart_traffic_detector/label_map_k400.txt’ saved [197944]

# %% [markdown]
# ### 3. Write App file and  Requirements file

# %% [markdown]
# #### 1. write Requirements File

# %%
# %%writefile requirements.txt
#
#
# # Core video processing
# moviepy==1.0.3
# opencv-python==4.9.0.80
# ffmpeg-python==0.2.0
#
# # Object detection (YOLOv8)
# ultralytics==8.1.5
#
#
# # Email alerts
# certifi
# email-validator
#
# # Streamlit (optional for dashboard)
# streamlit==1.27.2
#
# # For parsing configs and data
# PyYAML==6.0
# numpy==1.24.4
# pandas
#
# # Youtube  video library
# yt-dlp
# pyngrok
#
#
#
# # frontend and tunnel library
# pyngrok
# streamlit
# ultralytics
# Out:
# Overwriting requirements.txt

# %% [markdown]
# #### 2. write App file

# %%
# %%writefile /content/smart_traffic_detector/main/main_app.py
import os
import json
import subprocess
from typing import Dict, List, Any, Set

import cv2
import numpy as np
from moviepy.editor import VideoFileClip
from mmaction.apis import init_recognizer, inference_recognizer
from ultralytics import YOLO




#--------------------------------------------
# Environment Project Tree Structure Setup
#--------------------------------------------

work_dir = "/content/smart_traffic_detector"
model_config = "/content/mmaction2/configs/recognition/timesformer/timesformer_spaceOnly_8xb8-8x32x1-15e_kinetics400-rgb.py"
model_checkpoints = "/content/smart_traffic_detector/checkpoints/timesformer_spaceOnly_8xb8-8x32x1-15e_kinetics400-rgb_20220815-78f05367.pth"
label_map_path = "/content/smart_traffic_detector/label_map_k400.txt"




# ------------------------------------------------------------------
# Video Preprocessing
# ------------------------------------------------------------------
def split_video_into_clips(video_path: str, output_dir: str = "clips", clip_length: int = 10):
    """Split a  video into tubelets  (smaller clips (seconds))  via ffmpeg."""


    # Probe duration
    result = subprocess.run(
        ["ffprobe", "-v", "error", "-show_entries", "format=duration",
         "-of", "default=noprint_wrappers=1:nokey=1", video_path],
        capture_output=True, text=True
    )
    duration = float(result.stdout.strip()) if result.stdout.strip() else 0.0

    clips = []  # temorarily store splitted clips
    for start in range(0, int(duration), clip_length):  # iterate over the clip length at a step size of 10sec
        clip_name = f"{output_dir}/clip_{start:04d}.mp4"
        subprocess.run([
            "ffmpeg", "-y",
            "-ss", str(start),
            "-i", video_path,
            "-t", str(clip_length),
            "-vf", "scale=640:384",
            "-c:v", "libx264",
            "-pix_fmt", "yuv420p",
            clip_name
        ], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
        clips.append((clip_name, start))
    return clips


# ------------------------------
# Traffic Light Color Detection
# ------------------------------

def detect_traffic_light_color_simple(image, bbox, debug_id=None):
    """

    Returns: 'red', 'yellow', 'green', or 'unknown'.
    """
    x1, y1, x2, y2 = map(int, bbox)

    # Clip to image bounds
    h_img, w_img = image.shape[:2]
    x1 = max(0, min(x1, w_img - 1))
    x2 = max(0, min(x2, w_img))
    y1 = max(0, min(y1, h_img - 1))
    y2 = max(0, min(y2, h_img))
    if x2 <= x1 or y2 <= y1:
        return "unknown"

    roi = image[y1:y2, x1:x2]  # Grab the region of interest from the Detected Traffic Light
    if roi.size == 0:
        return "unknown"

    # Noise reduction
    roi = cv2.GaussianBlur(roi, (3, 3), 0)

    # increase contrast
    lab = cv2.cvtColor(roi, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    roi = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)

    # HSV  (Hue Saturation Value)
    hsv = cv2.cvtColor(roi, cv2.COLOR_BGR2HSV)

    # Split into 3 horizontal sections: Red Yellow and Green which falls in top, Mid and bottom of the traffic light respectively

    h = roi.shape[0]
    third = max(1, h // 3)
    sections = {                     # Grab  each section and store them based on the division
        "red": hsv[0:third, :],
        "yellow": hsv[third:2 * third, :],
        "green": hsv[2 * third:h, :]
    }

    # Broad HSV ranges (tune per camera)
    red_lower1 = np.array([0, 50, 20])
    red_upper1 = np.array([10, 255, 255])
    red_lower2 = np.array([160, 50, 20])
    red_upper2 = np.array([180, 255, 255])

    yellow_lower = np.array([15, 40, 40])
    yellow_upper = np.array([40, 255, 255])

    green_lower = np.array([30, 40, 40])
    green_upper = np.array([100, 255, 255])

     # Debbug traffic light section to detetct the correct light
    scores = {}
    if debug_id:
        dbg_dir = os.path.join(work_dir, "debug")
        os.makedirs(dbg_dir, exist_ok=True)
        cv2.imwrite(os.path.join(dbg_dir, f"tl_{debug_id}.jpg"), roi)
    else:
        dbg_dir = None


    # masking ROI to get values the approximate shape and the location of the color detected
    for color, section_hsv in sections.items():
        if color == "red":
            mask1 = cv2.inRange(section_hsv, red_lower1, red_upper1)
            mask2 = cv2.inRange(section_hsv, red_lower2, red_upper2)
            mask = cv2.bitwise_or(mask1, mask2)
        elif color == "yellow":
            mask = cv2.inRange(section_hsv, yellow_lower, yellow_upper)
        else:  # green
            mask = cv2.inRange(section_hsv, green_lower, green_upper)

        scores[color] = cv2.countNonZero(mask)  # count the number of the dominant color of each pixel in each section of the traffic light

        if dbg_dir:
            cv2.imwrite(os.path.join(dbg_dir, f"{color}_mask_{debug_id}.jpg"), mask)   # store Detected color

    dominant_color = max(scores, key=scores.get)
    total_pixels = roi.shape[0] * roi.shape[1]
    return dominant_color if total_pixels > 0 and (scores[dominant_color] / float(total_pixels)) > 0.002 else "unknown"


# ------------------------------
# Object Detection using Yolov8
# ------------------------------
_object_model = YOLO("yolov8n.pt")  # pretrained COCO

 # Return Respective classs id for the object detcted
if isinstance(_object_model.names, dict):
    CLASS_NAMES: Dict[int, str] = _object_model.names
elif isinstance(_object_model.names, (list, tuple)):
    CLASS_NAMES = {i: n for i, n in enumerate(_object_model.names)}
else:
    CLASS_NAMES = {}


def _get_cls_id(box) -> int:
    cid = getattr(box, "cls", None)
    if cid is None:
        return -1
    try:
        return int(cid.item())
    except Exception:
        try:
            return int(cid[0])
        except Exception:
            return int(cid)


def run_object_detection(clip_path: str) -> List[Dict[str, Any]]:
    """Run YOLO object detection on a video file and return list of detections."""
    results = _object_model(clip_path, stream=True)
    detections = []

    for frame_id, res in enumerate(results):
        frame = res.orig_img  # BGR numpy array

        boxes = getattr(res, "boxes", None)
        if boxes is None or len(boxes) == 0:
            continue

        for box_idx, box in enumerate(boxes):
            cls_id = _get_cls_id(box)
            cls_name = CLASS_NAMES.get(cls_id, f"class_{cls_id}")

            # get bounding box cordinate
            xyxy = box.xyxy
            if hasattr(xyxy, "cpu"):
                xyxy = xyxy.cpu().numpy()
            xyxy = np.array(xyxy).reshape(-1, 4)[0].tolist()

            # confidence check
            conf_attr = getattr(box, "conf", None)
            if conf_attr is not None:
                try:
                    conf_val = float(conf_attr.item())
                except Exception:
                    conf_val = float(conf_attr)
            else:
                conf_val = 0.0

            det = {
                "frame": frame_id,
                "class": cls_name,
                "confidence": conf_val,
                "bbox": xyxy,
            }

            # Traffic light color classification
            if cls_name == "traffic light":
                debug_id = f"{os.path.basename(clip_path)}_f{frame_id}_b{box_idx}"
                det["color"] = detect_traffic_light_color_simple(frame, xyxy, debug_id=debug_id)

            detections.append(det)

    return detections

#--------------
# Model Loader
#-------------
def load_model():
  _object_model = YOLO("yolov8n.pt")
  _action_model = init_recognizer(model_config, model_checkpoints, device="cpu")
  return _object_model, _action_model

_object_model, _action_model = load_model()

# ----------------------------------------------------
# Action Recognition  Using TimeSformer from MMAction
# ----------------------------------------------------


with open(label_map_path) as f:
    LABEL_MAP = [line.strip() for line in f.readlines()]


def run_action_recognition(clip_path: str) -> List[Dict[str, Any]]:
    """Return top-5 action predictions from MMAction2 model."""
    results = inference_recognizer(_action_model, clip_path)
    top5_scores, top5_labels = results.pred_score.topk(5)
    return [
        {"label": LABEL_MAP[int(label)], "score": float(score)}
        for label, score in zip(top5_labels, top5_scores)
    ]

# ----------------------
# clip Analysis
# ----------------------
def analyze_clip(clip_path: str, start_time: float):
    obj_dets = run_object_detection(clip_path)
    act_dets = run_action_recognition(clip_path)
    return {
        "clip": os.path.basename(clip_path),
        "start_time": start_time,
        "object_detections": obj_dets,
        "action_detections": act_dets
    }


# -------------------------------------------
# Violation Rules for both Action and Object
# -------------------------------------------
violation_rules = {
    "driving car": {
        "required_objects": ["traffic light", "car"],
        "threshold": 0.30,
        "description": "Vehicle driving – check for red-light violation"
    },
    "riding a bike": {
        "required_objects": ["bicycle", "person"],
        "threshold": 0.25,
        "description": "Bike riding – check for helmet use"
    },
    "motorcycling": {
        "required_objects": ["motorcycle", "person"],
        "threshold": 0.25,
        "description": "Motorcycle detected – possible no helmet"
    },
    "running": {
        "required_objects": ["person", "car"],
        "threshold": 0.30,
        "description": "Jaywalking or unsafe crossing"
    },
    "sitting": {
        "required_objects": ["person", "bus stop"],
        "threshold": 0.15,
        "description": "Loitering at bus stop"
    },
    "standing": {
        "required_objects": ["person"],
        "description": "Pedestrian blocking road"
    },
}

# Map logical -> detector labels (yolov8 was trained on COCO with 80 objects)
OBJECT_SYNONYMS = {
    "bus stop": ["bench", "stop sign"],
}


def _expand_required_objects(required: Set[str], detected_objects: Set[str]) -> Set[str]:
    """Expand logical rule objects into actual detector class names where needed."""
    expanded = set()
    for obj_name in required:
        if obj_name in detected_objects:
            expanded.add(obj_name)
            continue
        for syn in OBJECT_SYNONYMS.get(obj_name, []):
            if syn in detected_objects:
                expanded.add(syn)
                break
        else:
            expanded.add(obj_name)  # keep; may remain missing
    return expanded


# --------------------------
# Violation Detection Logic
# -------------------------
def detect_violations(result: Dict[str, Any]):
    violations = []
    obj_dets = result["object_detections"]
    detected_objects = set(obj["class"] for obj in obj_dets)

    # Aggregate traffic-light colors (any RED beats others)
    tl_colors = [obj.get("color", "unknown") for obj in obj_dets if obj["class"] == "traffic light"]
    traffic_light_status = "unknown"
    if any(c == "red" for c in tl_colors):
        traffic_light_status = "red"
    elif any(c == "yellow" for c in tl_colors):
        traffic_light_status = "yellow"
    elif any(c == "green" for c in tl_colors):
        traffic_light_status = "green"

    for action in result["action_detections"]:
        label, score = action["label"], action["score"]
        if label not in violation_rules:
            continue
        rule = violation_rules[label]

        if score < rule["threshold"]:
            print(f"⚠️ Action '{label}' below threshold: {score:.2f} < {rule['threshold']}")
            continue

        logical_required = set(rule["required_objects"])
        required = _expand_required_objects(logical_required, detected_objects)
        missing = {r for r in required if r not in detected_objects}


        # Red Light based Violations
        if not missing and traffic_light_status == "red":
            violations.append({
                "clip": result["clip"],
                "start_time": result["start_time"],
                "violation_type": label,
                "description": rule["description"],
                "score": score,
                "objects": list(logical_required)
            })
            print(f"⚠️ Violation Detected: {label}.")
        else:
            print(f"❌ Missing required objects for {label}: {missing}")

    return violations


# -----------------------------------------
# Run Violation Engine on All Clip Results
# ----------------------------------------
def run_violation_engine(processed_results: List[Dict[str, Any]]):
    all_violations = []
    for result in processed_results:
        v = detect_violations(result)
        if v:
            all_violations.extend(v)
    return all_violations


# --------------------------------
# Extract Violation Evidence Clip
# --------------------------------
def extract_violation_clip(input_path: str, output_path: str, start: float = 0, clip_duration: int = 5):
    video = VideoFileClip(input_path)
    video_duration = video.duration

    # Clamp start
    if start >= video_duration:
        start = max(0, video_duration - clip_duration)

    end = min(start + clip_duration, video_duration)
    print(f"Extracting from {start:.2f}s to {end:.2f}s (clip is {video_duration:.2f}s long)")

    clip = video.subclip(start, end)
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    clip.write_videofile(output_path, codec="libx264", audio_codec="aac")
    clip.close()
    video.close()


#------------------
# Email Funtion
#-----------------
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText

def send_violation_email(to_email, violator_name, violations):
    # Email sender config
    sender_email = "visionmarshalai@gmail.com"
    sender_password = "qvld tfnl ldsz wvaz"  # Use app password, NOT your email password
    subject = "Traffic Violation Report and Fine Notice"

    # Create message body
    body = f"Dear {violator_name},\n\n"
    body += "You have been found in violation of the following traffic rule(s):\n\n"

    total_fine = 0
    for i, v in enumerate(violations, 1):
        fine_amount = violation_rules[v['violation_type']]["fine"]
        total_fine += fine_amount
        body += f"{i}. Violation: {v['violation_type'].replace('_', ' ').title()}\n"
        body += f"   Description: {v['description']}\n"
        body += f"   Fine: ₦{fine_amount:,}\n\n"

    body += f"Total Fine: ₦{total_fine:,}\n\n"
    body += "Please address this issue within 7 days to avoid additional penalties.\n"
    body += "\nSincerely,\nTraffic Enforcement Authority"

    # Setup MIME
    msg = MIMEMultipart()
    msg['From'] = sender_email
    msg['To'] = to_email
    msg['Subject'] = subject
    msg.attach(MIMEText(body, 'plain'))

    # Connect and send
    try:
        server = smtplib.SMTP("smtp.gmail.com", 587)
        server.starttls()
        server.login(sender_email, sender_password)
        server.send_message(msg)
        server.quit()
        print(f"✔️ Email sent successfully to {to_email}")
    except Exception as e:
        print(f"❌ Failed to send email: {e}")

#--------------------
#Extract Plate number
#--------------------



#-------------------
# Violator Details
#-------------------
violator_name = "State Space Technologies"
to_email = "StatespaceTechnologies@gmail.com"


# ---------------
# Main Funtion
# ---------------
def main_func(video_path: str):
    """
    Video Path Can be from live feed or recorded video

    """

    #  Preprocess video into tubelet
    clips = split_video_into_clips(video_path, output_dir=os.path.join(work_dir,"clips"))
    processed_results = []

    # Detect objects + actions per tubelet
    for clip_path, start in clips:
        print(f"Analyzing {clip_path} (start at {start}s)...")
        result = analyze_clip(clip_path, start)
        processed_results.append(result)

    # Save analysed reult
    analysed_path = os.path.join(work_dir, "analysed_results.json")
    with open(analysed_path, "w") as f:
        json.dump(processed_results, f, indent=2)
    print(f"Analysis saved: {analysed_path}")

    # Check  for vioaltions
    violations = run_violation_engine(processed_results)

    # Extract evidence clips
    for violation in violations:
      if violation:
        clip = violation["clip"]
        start_time = violation["start_time"]
        violation_type = violation["violation_type"]
        violation_clip_name = os.path.join(work_dir, f"clips/{violation_type.replace(' ', '_').lower()}_{clip}")
        print(f"Saving violation clip as: {violation_clip_name}")
        input_clip_path = f"/content/smart_traffic_detector/clips/{clip}"
        extract_violation_clip(input_clip_path, violation_clip_name, start_time, clip_duration=5)

        send_violation_email(to_email, violator_name, violations)

    # Save violation log
    violation_log_path = os.path.join(work_dir,"violations", "violation_log.json")
    with open(violation_log_path, "w") as f:
        json.dump(violations, f, indent=2)
    print(f"Violation log saved: {violation_log_path}")

    print("Pipeline complete.")
    return processed_results, violations




# ----------
# CLI Entry
# ----------

if __name__ == "__main__":
    import argparse
    parser = argparse.ArgumentParser(description="Smart Traffic Violation Detection Pipeline")
    parser.add_argument("--video", type=str, required=True, help="Path to the input video file")
    args = parser.parse_args()
    main_func(args.video)
# Out:
# Overwriting /content/smart_traffic_detector/main/main_app.py

# %% [markdown]
# #### 4. Write Streamlit App

# %%
# %%writefile /content/smart_traffic_detector/streamlit_app.py

from pathlib import Path
import tempfile
import os
import json
import streamlit as st
from main.main_app import main_func

# -------------------------------
# Streamlit Page Configuration
# -------------------------------
st.set_page_config(
    page_title="🚦 Vision Marshal Ai",
    page_icon="🚨",
    layout="centered"
)

# -------------------------------
# Sidebar Info
# -------------------------------
st.sidebar.title("📖 How to use")
st.sidebar.markdown("""
1. Upload a traffic video (MP4, AVI, MOV, WEBM).
2. Click **'🚨 Check Violations'** to analyze the video.
3. Review detected violations and download logs/clips.
""")
st.sidebar.info("This tool uses AI to detect red-light running, jaywalking, and helmetless riding and other Infractions.")

# -------------------------------
# Main Title
# -------------------------------
st.title("🚦 Vision Marshal Ai")
st.markdown("""
Upload a traffic video to detect potential violations like **red-light running**,
**jaywalking**, or **helmetless riding**.
""")

# -------------------------------
# File Uploader
# -------------------------------
uploaded_video = st.file_uploader(
    "📤 Upload a video file to analyze",
    type=["mp4", "avi", "mov", "webm"]
)

# Initialize session state
if "violations" not in st.session_state:
    st.session_state["violations"] = None
    st.session_state["log_ready"] = False

# -------------------------------
# Main Logic
# -------------------------------
if uploaded_video:
    st.video(uploaded_video)

    # Save uploaded video to a temporary file
    with tempfile.NamedTemporaryFile(delete=False, suffix=".mp4") as temp_video:
        temp_video.write(uploaded_video.read())
        temp_video_path = temp_video.name

    if st.button("🚨 Check Violations"):
        st.info("⚙️ Starting analysis... please wait.")
        with st.spinner("Analyzing video for traffic violations..."):
            try:
                processed_result, violations = main_func(temp_video_path)

                # Save results to session state
                st.session_state["violations"] = violations
                st.session_state["log_ready"] = True

                if violations:
                    st.success(f"✅ Analysis complete: {len(violations)} violation(s) detected.")
                else:
                    st.success("✅ No violations detected in the video.")

            except Exception as e:
                st.error(f"❌ An error occurred during analysis:\n\n{e}")

            finally:
                # Clean up temporary video file
                os.remove(temp_video_path)

    # -------------------------------
    # Display Results (if any)
    # -------------------------------
    if st.session_state["log_ready"]:
        violations = st.session_state["violations"]

        # Download violation log
        log_json = json.dumps(violations, indent=2)
        st.download_button(
            label="⬇️ Download Violation Log",
            data=log_json,
            file_name="violation_log.json",
            mime="application/json"
        )

        # log inline
        if st.checkbox("📄 View Violation Log"):
            st.code(log_json, language="json")

        # Show detected violation clips
        if violations:
            st.subheader("📹 Violation Clips")
            for i, violation in enumerate(violations):
                st.markdown(f"---\n### 🚨 Violation {i+1}: {violation['violation_type']}")
                st.write(f"**Description**: {violation['description']}")
                st.write(f"**Score**: {violation['score']:.2f}")

                clip_path = os.path.join(
                    "/content/smart_traffic_detector/clips", violation["clip"]
                )

                if os.path.exists(clip_path):
                    st.video(clip_path)
                    with open(clip_path, "rb") as clip_file:
                        st.download_button(
                            label=f"⬇️ Download Clip {i+1}",
                            data=clip_file.read(),
                            file_name=violation["clip"],
                            mime="video/mp4",
                            key=f"download_clip_{i}"
                        )
                else:
                    st.warning(f"⚠️ Clip not found: {violation['clip']}")

else:
    st.info("👆 Upload a video file above to get started.")
# Out:
# Writing /content/smart_traffic_detector/streamlit_app.py

# %% [markdown]
# #### Write ` __init__file`

# %%
# %%writefile /content/smart_traffic_detector/main/__init__.py

from .main_app import main_func
# Out:
# Writing /content/smart_traffic_detector/main/__init__.py

# %%
# !rm -rf __pycache__ main/__pycache__

# %% [markdown]
# #### 4. Install Requirements

# %%
# !pip install --q -r requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 702.8/702.8 kB 21.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.9/757.9 kB 50.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 92.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 28.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 111.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 25.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 70.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 22.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 7.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, which is not installed.
# peft 0.16.0 requires transformers, which is not installed.
# openxlab 0.1.2 requires packaging~=24.0, but you have packaging 23.2 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.8 which is incompatible.
# xarray-einstats 0.9.1 requires numpy>=1.25, but you have numpy 1.24.4 which is incompatible.
# sphinx 8.2.3 requires requests>=2.30.0, but you have requests 2.28.2 which is incompatible.
# jaxlib 0.5.1 requires numpy>=1.25, but you have numpy 1.24.4 which is incompatible.
# pymc 5.25.1 requires numpy>=1.25.0, but you have numpy 1.24.4 which is incompatible.
# pymc 5.25.1 requires rich>=13.7.1, but you have rich 13.4.2 which is incompatible.
# datasets 4.0.0 requires requests>=2.32.2, but you have requests 2.28.2 which is incompatible.
# datasets 4.0.0 requires tqdm>=4.66.3, but you have tqdm 4.65.2 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.8 which is incompatible.
# yfinance 0.2.65 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.24.4 which is incompatible.
# arviz 0.22.0 requires numpy>=1.26.0, but you have numpy 1.24.4 which is incompatible.
# google-cloud-bigquery 3.35.1 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.24.4 which is incompatible.
# pytensor 2.31.7 requires filelock>=3.15, but you have filelock 3.14.0 which is incompatible.
# db-dtypes 1.4.3 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# dataproc-spark-connect 0.8.3 requires tqdm>=4.67, but you have tqdm 4.65.2 which is incompatible.
# jax 0.5.2 requires numpy>=1.25, but you have numpy 1.24.4 which is incompatible.
# xarray 2025.7.1 requires numpy>=1.26, but you have numpy 1.24.4 which is incompatible.
# xarray 2025.7.1 requires packaging>=24.1, but you have packaging 23.2 which is incompatible.

# %%
# !cp /content/mmaction2/tools/data/kinetics/label_map_k400.txt /content/smart_traffic_detector

# %% [markdown]
# ## `4. Local Testing`

# %% [markdown]
# #### 1. Download Youtube Video

# %%
# !yt-dlp "https://youtu.be/lBRWEeuuMpE?si=AKzynUYzr0CcVQCq" -o /content/smart_traffic_detector/test_video_2
# Out:
# [youtube] Extracting URL: https://youtu.be/lBRWEeuuMpE?si=AKzynUYzr0CcVQCq
# [youtube] lBRWEeuuMpE: Downloading webpage
# [youtube] lBRWEeuuMpE: Downloading tv client config
# [youtube] lBRWEeuuMpE: Downloading player cbd59245-main
# [youtube] lBRWEeuuMpE: Downloading tv player API JSON
# [youtube] lBRWEeuuMpE: Downloading ios player API JSON
# WARNING: [youtube] lBRWEeuuMpE: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] lBRWEeuuMpE: Downloading m3u8 information
# [info] Testing format 270
# [info] Testing format 234
# [info] lBRWEeuuMpE: Downloading 1 format(s): 270+234
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 3
# [download] Destination: /content/smart_traffic_detector/test_video_2.f270.mp4
# [download] 100% of    3.70MiB in 00:00:01 at 2.26MiB/s
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 3
# [download] Destination: /content/smart_traffic_detector/test_video_2.f234.mp4
# [download] 100% of  256.80KiB in 00:00:00 at 2.77MiB/s
# [Merger] Merging formats into "/content/smart_traffic_detector/test_video_2.mp4"
# Deleting original file /content/smart_traffic_detector/test_video_2.f234.mp4 (pass -k to keep)
# Deleting original file /content/smart_traffic_detector/test_video_2.f270.mp4 (pass -k to keep)

# %% [markdown]
# #### 2. Local Inferencing

# %%
 # !python /content/smart_traffic_detector/main/main_app.py  --video /content/smart_traffic_detector/test_video_2.webm
# Out:
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.23M/6.23M [00:00<00:00, 207MB/s]
# Loads checkpoint by local backend from path: /content/smart_traffic_detector/checkpoints/timesformer_spaceOnly_8xb8-8x32x1-15e_kinetics400-rgb_20220815-78f05367.pth
# Analysis saved: /content/smart_traffic_detector/analysed_results.json
# Violation log saved: /content/smart_traffic_detector/violations/violation_log.json
# Pipeline complete.

# %% [markdown]
# #  ***Frontend Setup***

# %% [markdown]
# #### 1. Get Local tunnel Password

# %%
# !curl ifconfig.me
# Out:
# 34.87.134.22

# %% [markdown]
# #### 2. Deploy Streamlit Prototype

# %%
# !streamlit run /content/smart_traffic_detector/streamlit_app.py & npx localtunnel --port 8501
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to False.
#
# ⠏⠋⠙⠹
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.87.134.22:8501
#
# your url is: https://smart-aliens-start.loca.lt
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# Loads checkpoint by local backend from path: /content/smart_traffic_detector/checkpoints/timesformer_spaceOnly_8xb8-8x32x1-15e_kinetics400-rgb_20220815-78f05367.pth
# Analyzing /content/smart_traffic_detector/clips/clip_0000.mp4 (start at 0s)...
#
# video 1/1 (1/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 6 traffic lights, 1 fire hydrant, 107.9ms
# video 1/1 (2/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 6 traffic lights, 1 fire hydrant, 8.2ms
# video 1/1 (3/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 7.3ms
# video 1/1 (4/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 7.0ms
# video 1/1 (5/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 6 traffic lights, 1 fire hydrant, 12.7ms
# video 1/1 (6/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.7ms
# video 1/1 (7/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.9ms
# video 1/1 (8/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.6ms
# video 1/1 (9/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.7ms
# video 1/1 (10/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.3ms
# video 1/1 (11/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 9.9ms
# video 1/1 (12/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 8.5ms
# video 1/1 (13/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.3ms
# video 1/1 (14/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.3ms
# video 1/1 (15/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 7.6ms
# video 1/1 (16/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 8.1ms
# video 1/1 (17/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.4ms
# video 1/1 (18/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.4ms
# video 1/1 (19/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.9ms
# video 1/1 (20/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.7ms
# video 1/1 (21/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 7.7ms
# video 1/1 (22/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 7.4ms
# video 1/1 (23/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 7.1ms
# video 1/1 (24/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 9.0ms
# video 1/1 (25/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 8.1ms
# video 1/1 (26/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 9.5ms
# video 1/1 (27/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 7.4ms
# video 1/1 (28/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 8.0ms
# video 1/1 (29/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.4ms
# video 1/1 (30/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.0ms
# video 1/1 (31/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.2ms
# video 1/1 (32/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 7.0ms
# video 1/1 (33/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.9ms
# video 1/1 (34/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.6ms
# video 1/1 (35/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.9ms
# video 1/1 (36/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 9.9ms
# video 1/1 (37/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 11.4ms
# video 1/1 (38/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 5 traffic lights, 1 fire hydrant, 7.8ms
# video 1/1 (39/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 7.3ms
# video 1/1 (40/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 7.1ms
# video 1/1 (41/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 7.9ms
# video 1/1 (42/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 6.9ms
# video 1/1 (43/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.7ms
# video 1/1 (44/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.7ms
# video 1/1 (45/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.8ms
# video 1/1 (46/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 7.6ms
# video 1/1 (47/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 7.0ms
# video 1/1 (48/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.9ms
# video 1/1 (49/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 7.2ms
# video 1/1 (50/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 13.3ms
# video 1/1 (51/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 8.8ms
# video 1/1 (52/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 11.1ms
# video 1/1 (53/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 12.1ms
# video 1/1 (54/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 9.9ms
# video 1/1 (55/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 9.5ms
# video 1/1 (56/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 10.1ms
# video 1/1 (57/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 9.4ms
# video 1/1 (58/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 5 traffic lights, 1 fire hydrant, 8.1ms
# video 1/1 (59/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 5 traffic lights, 1 fire hydrant, 10.0ms
# video 1/1 (60/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 12.0ms
# video 1/1 (61/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 14.3ms
# video 1/1 (62/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.5ms
# video 1/1 (63/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.1ms
# video 1/1 (64/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.7ms
# video 1/1 (65/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 7.0ms
# video 1/1 (66/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 7.2ms
# video 1/1 (67/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 9.5ms
# video 1/1 (68/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 10.4ms
# video 1/1 (69/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 9.5ms
# video 1/1 (70/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 14.1ms
# video 1/1 (71/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 10.9ms
# video 1/1 (72/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 12.7ms
# video 1/1 (73/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 7.8ms
# video 1/1 (74/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 5 traffic lights, 1 fire hydrant, 10.3ms
# video 1/1 (75/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 7.1ms
# video 1/1 (76/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 10.7ms
# video 1/1 (77/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 10.9ms
# video 1/1 (78/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 12.6ms
# video 1/1 (79/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 10.6ms
# video 1/1 (80/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 10.4ms
# video 1/1 (81/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 10.6ms
# video 1/1 (82/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 11.3ms
# video 1/1 (83/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 5 traffic lights, 1 fire hydrant, 11.1ms
# video 1/1 (84/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 10.4ms
# video 1/1 (85/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 11.1ms
# video 1/1 (86/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 13.8ms
# video 1/1 (87/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 2 cars, 4 traffic lights, 1 fire hydrant, 15.6ms
# video 1/1 (88/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 8.8ms
# video 1/1 (89/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (90/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (91/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (92/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (93/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (94/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.0ms
# video 1/1 (95/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (96/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.7ms
# video 1/1 (97/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 7.8ms
# video 1/1 (98/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (99/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (100/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 5.9ms
# video 1/1 (101/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (102/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (103/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.9ms
# video 1/1 (104/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (105/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 1 bus, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (106/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 1 bus, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (107/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 1 bus, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (108/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 1 bus, 5 traffic lights, 1 fire hydrant, 6.0ms
# video 1/1 (109/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 1 bus, 5 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (110/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 1 bus, 5 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (111/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 1 bus, 5 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (112/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 1 bus, 5 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (113/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 1 bus, 5 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (114/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 1 bus, 5 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (115/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 1 bus, 5 traffic lights, 1 fire hydrant, 10.2ms
# video 1/1 (116/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 7.0ms
# video 1/1 (117/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 1 bus, 5 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (118/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (119/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (120/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (121/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 5 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (122/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 1 bus, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (123/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (124/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (125/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (126/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (127/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (128/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (129/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (130/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (131/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (132/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (133/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 5.9ms
# video 1/1 (134/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (135/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 9 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (136/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 8 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (137/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (138/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 8 cars, 4 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (139/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 8 cars, 4 traffic lights, 1 fire hydrant, 6.6ms
# video 1/1 (140/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (141/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.7ms
# video 1/1 (142/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (143/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (144/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 7.5ms
# video 1/1 (145/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.7ms
# video 1/1 (146/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (147/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 8 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (148/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (149/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 3 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (150/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 3 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (151/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 3 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (152/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 3 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (153/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 3 traffic lights, 1 fire hydrant, 6.6ms
# video 1/1 (154/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 3 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (155/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 3 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (156/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 3 traffic lights, 1 fire hydrant, 7.8ms
# video 1/1 (157/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 3 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (158/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 3 traffic lights, 1 fire hydrant, 6.7ms
# video 1/1 (159/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (160/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (161/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (162/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 7.1ms
# video 1/1 (163/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (164/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (165/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (166/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (167/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.6ms
# video 1/1 (168/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (169/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (170/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 9.6ms
# video 1/1 (171/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 9.6ms
# video 1/1 (172/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (173/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (174/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (175/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.0ms
# video 1/1 (176/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (177/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (178/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (179/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (180/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (181/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (182/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.0ms
# video 1/1 (183/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 10.1ms
# video 1/1 (184/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (185/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (186/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (187/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (188/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (189/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.0ms
# video 1/1 (190/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 5.9ms
# video 1/1 (191/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (192/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (193/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (194/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (195/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 1 person, 5 cars, 4 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (196/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 1 person, 6 cars, 4 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (197/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 1 person, 6 cars, 4 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (198/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 8.5ms
# video 1/1 (199/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (200/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (201/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 1 person, 6 cars, 4 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (202/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 1 person, 6 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (203/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 1 person, 6 cars, 5 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (204/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 1 person, 6 cars, 5 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (205/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 1 person, 6 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (206/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (207/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (208/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (209/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 8.9ms
# video 1/1 (210/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (211/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (212/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 1 person, 6 cars, 5 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (213/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 1 person, 6 cars, 5 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (214/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 1 person, 5 cars, 5 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (215/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 1 person, 5 cars, 5 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (216/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 5 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (217/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.0ms
# video 1/1 (218/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 1 person, 4 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (219/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (220/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (221/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (222/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (223/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (224/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 5 traffic lights, 1 fire hydrant, 9.9ms
# video 1/1 (225/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 9.3ms
# video 1/1 (226/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (227/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 7.6ms
# video 1/1 (228/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (229/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (230/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 6 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (231/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (232/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (233/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (234/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (235/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (236/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (237/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 6.7ms
# video 1/1 (238/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (239/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (240/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.6ms
# video 1/1 (241/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (242/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.7ms
# video 1/1 (243/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (244/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (245/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 7.3ms
# video 1/1 (246/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (247/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 5 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (248/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 5 traffic lights, 1 fire hydrant, 8.6ms
# video 1/1 (249/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 5 traffic lights, 1 fire hydrant, 6.6ms
# video 1/1 (250/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (251/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 3 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (252/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 7 cars, 3 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (253/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.0ms
# video 1/1 (254/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (255/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (256/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (257/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (258/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (259/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 5 traffic lights, 1 fire hydrant, 6.7ms
# video 1/1 (260/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 5 traffic lights, 1 fire hydrant, 8.8ms
# video 1/1 (261/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (262/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 5 traffic lights, 1 fire hydrant, 7.1ms
# video 1/1 (263/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 5 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (264/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (265/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (266/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (267/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (268/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (269/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 5 traffic lights, 1 fire hydrant, 6.7ms
# video 1/1 (270/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 2 cars, 5 traffic lights, 1 fire hydrant, 6.7ms
# video 1/1 (271/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 2 cars, 5 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (272/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 2 cars, 5 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (273/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 2 cars, 5 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (274/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 2 cars, 5 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (275/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 2 cars, 5 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (276/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 2 cars, 5 traffic lights, 1 fire hydrant, 7.8ms
# video 1/1 (277/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 5 traffic lights, 1 fire hydrant, 11.5ms
# video 1/1 (278/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 5 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (279/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 5 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (280/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 2 cars, 5 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (281/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 2 cars, 5 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (282/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 2 cars, 5 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (283/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 2 cars, 5 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (284/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 2 cars, 5 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (285/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 2 cars, 5 traffic lights, 1 fire hydrant, 7.7ms
# video 1/1 (286/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 5 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (287/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 5 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (288/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 2 cars, 5 traffic lights, 1 fire hydrant, 8.3ms
# video 1/1 (289/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 2 cars, 5 traffic lights, 1 fire hydrant, 7.5ms
# video 1/1 (290/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 2 cars, 4 traffic lights, 1 fire hydrant, 6.6ms
# video 1/1 (291/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (292/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 5 traffic lights, 1 fire hydrant, 6.0ms
# video 1/1 (293/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 5 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (294/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.7ms
# video 1/1 (295/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 8.7ms
# video 1/1 (296/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (297/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 2 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (298/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 2 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (299/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 2 cars, 4 traffic lights, 1 fire hydrant, 7.3ms
# video 1/1 (300/300) /content/smart_traffic_detector/clips/clip_0000.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.9ms
# Speed: 1.1ms preprocess, 7.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 08/06 16:22:43 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 08/06 16:22:43 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# Analyzing /content/smart_traffic_detector/clips/clip_0010.mp4 (start at 10s)...
#
# video 1/1 (1/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 12.7ms
# video 1/1 (2/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (3/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (4/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (5/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (6/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 2 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (7/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (8/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (9/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (10/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (11/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (12/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.6ms
# video 1/1 (13/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 5 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (14/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 5 traffic lights, 1 fire hydrant, 6.6ms
# video 1/1 (15/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (16/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (17/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (18/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (19/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.7ms
# video 1/1 (20/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (21/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (22/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (23/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (24/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (25/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (26/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (27/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (28/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (29/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.6ms
# video 1/1 (30/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (31/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 7.6ms
# video 1/1 (32/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.0ms
# video 1/1 (33/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.0ms
# video 1/1 (34/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (35/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (36/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.6ms
# video 1/1 (37/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (38/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.6ms
# video 1/1 (39/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.9ms
# video 1/1 (40/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (41/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.6ms
# video 1/1 (42/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.2ms
# video 1/1 (43/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (44/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (45/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.7ms
# video 1/1 (46/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (47/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 3 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (48/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (49/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (50/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (51/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.6ms
# video 1/1 (52/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (53/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# ...
# video 1/1 (72/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 5 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (73/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 5 cars, 5 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (74/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (75/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (76/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.0ms
# video 1/1 (77/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (78/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 5 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (79/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 5 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (80/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (81/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (82/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (83/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 5 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (84/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (85/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (86/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (87/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (88/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (89/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (90/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (91/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 9.3ms
# video 1/1 (92/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (93/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (94/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 7.6ms
# video 1/1 (95/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 8 cars, 4 traffic lights, 1 fire hydrant, 7.0ms
# video 1/1 (96/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (97/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (98/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (99/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 8 cars, 4 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (100/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 9 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (101/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (102/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 8 cars, 4 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (103/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.9ms
# video 1/1 (104/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (105/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (106/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.6ms
# video 1/1 (107/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 9 cars, 4 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (108/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (109/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 9.8ms
# video 1/1 (110/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 9.1ms
# video 1/1 (111/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (112/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.7ms
# video 1/1 (113/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (114/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (115/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (116/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.6ms
# video 1/1 (117/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (118/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.4ms
# video 1/1 (119/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (120/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.1ms
# video 1/1 (121/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (122/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (123/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.6ms
# video 1/1 (124/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.6ms
# video 1/1 (125/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 6.6ms
# video 1/1 (126/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (127/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.2ms
# video 1/1 (128/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 8 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (129/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 7.0ms
# video 1/1 (130/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.3ms
# video 1/1 (131/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 6.5ms
# video 1/1 (132/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 10.1ms
# video 1/1 (133/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 10.0ms
# video 1/1 (134/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 9.8ms
# video 1/1 (135/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 10.5ms
# video 1/1 (136/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 10.4ms
# video 1/1 (137/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 11.0ms
# video 1/1 (138/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 7 cars, 4 traffic lights, 1 fire hydrant, 8.3ms
# video 1/1 (139/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 12.4ms
# video 1/1 (140/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 7.7ms
# video 1/1 (141/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 11.4ms
# video 1/1 (142/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 12.2ms
# video 1/1 (143/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 5 cars, 4 traffic lights, 1 fire hydrant, 11.1ms
# video 1/1 (144/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 8.9ms
# video 1/1 (145/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 7.2ms
# video 1/1 (146/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 6 cars, 4 traffic lights, 1 fire hydrant, 11.3ms
# video 1/1 (147/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 8.1ms
# video 1/1 (148/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.0ms
# video 1/1 (149/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 6.8ms
# video 1/1 (150/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 8.8ms
# video 1/1 (151/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.9ms
# video 1/1 (152/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 9.1ms
# video 1/1 (153/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.7ms
# video 1/1 (154/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.6ms
# video 1/1 (155/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.3ms
# video 1/1 (156/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 9.1ms
# video 1/1 (157/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.2ms
# video 1/1 (158/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.3ms
# video 1/1 (159/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 10.1ms
# video 1/1 (160/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 8.7ms
# video 1/1 (161/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.5ms
# video 1/1 (162/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 8.0ms
# video 1/1 (163/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.9ms
# video 1/1 (164/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.9ms
# video 1/1 (165/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.8ms
# video 1/1 (166/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 8.1ms
# video 1/1 (167/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 9.1ms
# video 1/1 (168/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.3ms
# video 1/1 (169/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.5ms
# video 1/1 (170/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.3ms
# video 1/1 (171/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.6ms
# video 1/1 (172/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.4ms
# video 1/1 (173/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 9.9ms
# video 1/1 (174/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.1ms
# video 1/1 (175/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.0ms
# video 1/1 (176/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.3ms
# video 1/1 (177/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.8ms
# video 1/1 (178/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 4 traffic lights, 1 fire hydrant, 7.6ms
# video 1/1 (179/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 5 traffic lights, 1 fire hydrant, 9.5ms
# video 1/1 (180/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 5 traffic lights, 1 fire hydrant, 8.7ms
# video 1/1 (181/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 5 traffic lights, 1 fire hydrant, 7.2ms
# video 1/1 (182/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 5 traffic lights, 1 fire hydrant, 7.1ms
# video 1/1 (183/183) /content/smart_traffic_detector/clips/clip_0010.mp4: 384x640 4 cars, 5 traffic lights, 1 fire hydrant, 7.0ms
# Speed: 1.1ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Analysis saved: /content/smart_traffic_detector/analysed_results.json
# ⚠️ Action 'driving car' below threshold: 0.28 < 0.3
# ⚠️ Action 'motorcycling' below threshold: 0.14 < 0.25
# ⚠️ Action 'riding a bike' below threshold: 0.09 < 0.25
# ⚠️ Violation Detected: driving car.
# ⚠️ Action 'motorcycling' below threshold: 0.13 < 0.25
# ⚠️ Action 'riding a bike' below threshold: 0.08 < 0.25
# Saving violation clip as: /content/smart_traffic_detector/clips/driving_car_clip_0010.mp4
# Extracting from 1.10s to 6.10s (clip is 6.10s long)
# Moviepy - Building video /content/smart_traffic_detector/clips/driving_car_clip_0010.mp4.
# Moviepy - Writing video /content/smart_traffic_detector/clips/driving_car_clip_0010.mp4
#
# Moviepy - Done !
# Moviepy - video ready /content/smart_traffic_detector/clips/driving_car_clip_0010.mp4
# /root/.npm/_npx/75ac80b86e83d4a2/node_modules/localtunnel/bin/lt.js:81
#     throw err;
#     ^
#
# Error: connection refused: localtunnel.me:20889 (check your firewall settings)
#     at Socket.<anonymous> (/root/.npm/_npx/75ac80b86e83d4a2/node_modules/localtunnel/lib/TunnelCluster.js:52:11)
#     at Socket.emit (node:events:524:28)
#     at emitErrorNT (node:internal/streams/destroy:169:8)
#     at emitErrorCloseNT (node:internal/streams/destroy:128:3)
#     at process.processTicksAndRejections (node:internal/process/task_queues:82:21)
#
# Node.js v20.19.0
# ⠙  Stopping...
